# %% [markdown]
# ### Python Basic Assignment_1 26-02-2022 from Sachin Garg

# %% [markdown]
# # 1. In the below elements which of them are values or an expression? eg:- values can be integer or string and expressions will be mathematical operators.
# *, 'hello', -87.8, - , / , + ,6
#
# Answer:
#
# Values: 'hello', -87.8, 6
#
# Expression: *, -, /, +

# %% [markdown]
# # 2. What is the difference between string and variable?
#
# String: String can be any Aplhanumeric characters/words enclosed in single or double quotes. String is denoted as str. String is the data which is stored.
# Variable: Variables are the symbols/ keywords that used to store Data in the memory.

# %% [markdown]
# # 3. Describe three different data types.
# Data Types:
# 1. Integers: Intgers are numeric characters. They are either positive or negative.
# 2. Float: floats are numeric values with decimal places. e.g 2.5, 58.56
# 3. Booleans: Booleans in python are True or False. True = 1, False = 0
# 4. String
# 5. List: List of words or alphanumeric characters enclosed in [] brackets. They are mutable.
# 6. Sets: Sequential order of Words or numeric characters. They are enclosed in {}
# 7. Tuples
# 8. Dictionary

# %% [markdown]
# # 4. What is an expression made up of? What do all expressions do?
#
# An expression is a combination of operators and operands that is interpreted to produce some other value. In any programming language, an expression is evaluated as per the precedence of its operators.

# %% [markdown]
# # 5. This assignment statements, like spam = 10. What is the difference between an expression and a statement?
#
# An Expression is a combinaton of Operators and Operands that is interpreted to produce some value. Whereas Statement is like a print command to be by the python.

# %% [markdown]
# # 6. After running the following code, what does the variable bacon contain?
# bacon = 22
# bacon + 1
#
#
# Answer:
# 1. 22
# 2. 23

# %% [markdown]
# # 7. What should the values of the following two terms be?
# 'spam' + 'spamspam'
# 'spam' * 3
#
# Answer:
# 1. 'spamspamspam'
# 2. 'spamspamspam'

# %% [markdown]
# # 8. Why is eggs a valid variable name while 100 is invalid?
#
# Answer:
#     Because Variable cannot begin with a number.

# %% [markdown]
# # 9. What three functions can be used to get the integer, floating-point number, or string version of a value?
#
# Answer: The int() , float() , and str( ) functions will be sued to get the integer, floating-point number, and string version of a value.

# %% [markdown]
# # 10. Why does this expression cause an error? How can you fix it?
# 'I have eaten ' + 99 + ' burritos.'
#
# Answer:
#
# 'I have eaten ' + str(99) + ' burritos.'
